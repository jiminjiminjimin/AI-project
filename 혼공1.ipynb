# %%
import gdown
gdown.download('https://bit.ly/3eecMKZ', '남산도서관 장서 대출목록 (2021년 04월).csv', quiet = False)
# Out:
# Downloading...
# From: https://bit.ly/3eecMKZ
# To: /content/남산도서관 장서 대출목록 (2021년 04월).csv
# 100%|██████████| 58.1M/58.1M [00:00<00:00, 58.6MB/s]
# '남산도서관 장서 대출목록 (2021년 04월).csv'

# %%
with open('서울특별시교육청남산도서관 장서 대출목록 (2023년 08월).csv', encoding = 'EUC-KR') as f:
    print(f.readline())
    print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","(정찬주 장편소설)훨훨","정찬주 지음","열린세상","1995","9788979180480","","0","2","813.6","1","9","2023-08-28",

# %%
import pandas as pd
df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2023년 08월).csv', encoding = 'EUC-KR')
# Out:
# <ipython-input-9-98333e8e592a>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2023년 08월).csv', encoding = 'EUC-KR')

# %%
df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2023년 08월).csv', encoding = 'EUC-KR', low_memory = False)

# %%
df.head()
# Out:
#    번호                               도서명                            저자  \
# 0   1                      (정찬주 장편소설)훨훨                        정찬주 지음
# 1   2                      (정찬주 장편소설)훨훨                        정찬주 지음
# 2   3  미움받을 용기:사랑과 진정한 자립에 대한 아들러의 가르침   기시미 이치로,고가 후미타케 [공]지음;전경아 옮김
# 3   4  미움받을 용기 :자유롭고 행복한 삶을 위한 아들러의 가르침     기시미 이치로,고가 후미타케 지음;전경아 옮김
# 4   5  아무튼, 잠수 :힘을 줘서 움켜잡을 수 없는 게 바다였다                         하미나 지음
#
#         출판사             발행년도           ISBN  세트 ISBN 부가기호   권 주제분류번호  도서권수  \
# 0      열린세상             1995  9788979180480      NaN    0   2  813.6     1
# 1      열린세상             1995  9788979180473      NaN    0   1  813.6     1
# 2  인플루엔셜(주)  2022(2023 개정2쇄)  9791168340787      NaN    0   2    189     1
# 3  인플루엔셜(주)  2022(2023 개정2쇄)  9791168340770      NaN    0   1    189     1
# 4        위고             2023  9791193044056      NaN    0  58    818     1
#
#    대출건수        등록일자  Unnamed: 13
# 0     9  2023-08-28          NaN
# ...

# %%
df.to_csv('ns_202308.csv')

# %%
with open('ns_202308.csv') as f:
    for i in range(3):
        print(f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,(정찬주 장편소설)훨훨,정찬주 지음,열린세상,1995,9788979180480,,0,2,813.6,1,9,2023-08-28,
# 1,2,(정찬주 장편소설)훨훨,정찬주 지음,열린세상,1995,9788979180473,,0,1,813.6,1,7,2023-08-28,

# %%
ns_df = pd.read_csv('ns_202308.csv', low_memory = False)
ns_df.head()
# Out:
#    Unnamed: 0  번호                               도서명  \
# 0           0   1                      (정찬주 장편소설)훨훨
# 1           1   2                      (정찬주 장편소설)훨훨
# 2           2   3  미움받을 용기:사랑과 진정한 자립에 대한 아들러의 가르침
# 3           3   4  미움받을 용기 :자유롭고 행복한 삶을 위한 아들러의 가르침
# 4           4   5  아무튼, 잠수 :힘을 줘서 움켜잡을 수 없는 게 바다였다
#
#                              저자       출판사             발행년도           ISBN  \
# 0                        정찬주 지음      열린세상             1995  9788979180480
# 1                        정찬주 지음      열린세상             1995  9788979180473
# 2  기시미 이치로,고가 후미타케 [공]지음;전경아 옮김  인플루엔셜(주)  2022(2023 개정2쇄)  9791168340787
# 3     기시미 이치로,고가 후미타케 지음;전경아 옮김  인플루엔셜(주)  2022(2023 개정2쇄)  9791168340770
# 4                        하미나 지음        위고             2023  9791193044056
#
#    세트 ISBN 부가기호   권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0      NaN    0   2  813.6     1     9  2023-08-28          NaN
# 1      NaN    0   1  813.6     1     7  2023-08-28          NaN
# ...

# %%
ns_df = pd.read_csv('ns_202308.csv', index_col = 0, low_memory = False)
ns_df.head()
# Out:
#    번호                               도서명                            저자  \
# 0   1                      (정찬주 장편소설)훨훨                        정찬주 지음
# 1   2                      (정찬주 장편소설)훨훨                        정찬주 지음
# 2   3  미움받을 용기:사랑과 진정한 자립에 대한 아들러의 가르침   기시미 이치로,고가 후미타케 [공]지음;전경아 옮김
# 3   4  미움받을 용기 :자유롭고 행복한 삶을 위한 아들러의 가르침     기시미 이치로,고가 후미타케 지음;전경아 옮김
# 4   5  아무튼, 잠수 :힘을 줘서 움켜잡을 수 없는 게 바다였다                         하미나 지음
#
#         출판사             발행년도           ISBN  세트 ISBN 부가기호   권 주제분류번호  도서권수  \
# 0      열린세상             1995  9788979180480      NaN    0   2  813.6     1
# 1      열린세상             1995  9788979180473      NaN    0   1  813.6     1
# 2  인플루엔셜(주)  2022(2023 개정2쇄)  9791168340787      NaN    0   2    189     1
# 3  인플루엔셜(주)  2022(2023 개정2쇄)  9791168340770      NaN    0   1    189     1
# 4        위고             2023  9791193044056      NaN    0  58    818     1
#
#    대출건수        등록일자  Unnamed: 13
# 0     9  2023-08-28          NaN
# ...

# %%
df.to_csv('ns_202308.csv', index = False)
