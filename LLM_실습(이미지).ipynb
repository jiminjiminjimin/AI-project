# %%
# !pip install langchain
# !pip install openai
# !pip install langchain-openai
# !pip install langchain-community
# !pip install pyserial
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 682.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.2/290.2 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.6/375.6 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 19.9 MB/s eta 0:00:00
# ...

# %%
import os

os.environ["OPENAI_API_KEY"] = ''

# %%
import base64

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
from langchain_openai import ChatOpenAI
llm= ChatOpenAI(model_name="gpt-4o-mini", temperature = 1)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage

image = encode_image("./human_count.jpg")

messages =[   SystemMessage(content="너는 이미지에 있는 사람을 카운하는 봇이야."),
        HumanMessage(
            content=[
                {"type": "text",
                 "text": "이미지에 몇 명의 사람이 있어"},
                {
                    "type": "image_url",
                    "image_url": {"url": f"data:image/jpeg;base64,{image}"},
                },
            ]
        )
    ]

result = llm.invoke(messages)
result.content
# Out:
# '이미지에는 총 5명의 사람이 있습니다.'

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

llm = ChatOpenAI(model_name = "gpt-4o-mini", temperature = 1)

image = encode_image("./food.jpeg")

messages =[

        SystemMessage(content="너는 이미지에 있는 객체 종류에 대해서 모두 말해주는 봇이야."),
        HumanMessage(
            content=[
                {"type": "text",
                 "text": "이미지를 분석해줘"},
                {
                    "type": "image_url",
                    "image_url": {"url": f"data:image/jpeg;base64,{image}"},
                },
            ]
        )
    ]

result = llm.invoke(messages)
result
# Out:
# AIMessage(content='이미지에는 다음과 같은 물건들이 있습니다:\n\n1. **계란** - 판에 담긴 흰색 계란들.\n2. **치즈** - 포장된 원형의 치즈.\n3. **양파** - 네트에 담긴 여러 개의 작은 양파.\n4. **주황색 채소** - 아마 당근일 것으로 보이는 채소가 포장되어 있음.\n5. **올리브** - 포장된 그린 올리브.\n6. **호박** - 두 개의 녹색 호박.\n\n이 품목들은 요리를 위한 재료로 사용될 수 있습니다.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 138, 'prompt_tokens': 36869, 'total_tokens': 37007, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_e9627b5346', 'finish_reason': 'stop', 'logprobs': None}, id='run-7157c2f8-0760-4fb1-a81a-9edd79a5814a-0')

# %%
print(result.content)
# Out:
# 이미지에는 다음과 같은 물건들이 있습니다:
#
# 1. **계란** - 판에 담긴 흰색 계란들.
# 2. **치즈** - 포장된 원형의 치즈.
# 3. **양파** - 네트에 담긴 여러 개의 작은 양파.
# 4. **주황색 채소** - 아마 당근일 것으로 보이는 채소가 포장되어 있음.
# 5. **올리브** - 포장된 그린 올리브.
# 6. **호박** - 두 개의 녹색 호박.
#
# 이 품목들은 요리를 위한 재료로 사용될 수 있습니다.
